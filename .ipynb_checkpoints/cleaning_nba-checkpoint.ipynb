# %%
import pandas as pd

# %% [markdown]
# ### Load mvps

# %%
mvps = pd.read_csv('mvps.csv')
mvps
# Out:
#      Unnamed: 0 Rank             Player  Age   Tm  First  Pts Won  Pts Max  \
# 0             0    1     Michael Jordan   27  CHI   77.0    891.0      960
# 1             1    2      Magic Johnson   31  LAL   10.0    497.0      960
# 2             2    3     David Robinson   25  SAS    6.0    476.0      960
# 3             3    4    Charles Barkley   27  PHI    2.0    222.0      960
# 4             4    5        Karl Malone   27  UTA    0.0    142.0      960
# ..          ...  ...                ...  ...  ...    ...      ...      ...
# 469          10   11  Russell Westbrook   32  WAS    0.0      5.0     1010
# 470          11   12        Ben Simmons   24  PHI    0.0      3.0     1010
# 471          12  13T       James Harden   31  TOT    0.0      1.0     1010
# 472          13  13T       LeBron James   36  LAL    0.0      1.0     1010
# 473          14  13T      Kawhi Leonard   29  LAC    0.0      1.0     1010
#
# ...

# %% [markdown]
# # clean mvps

# %%
# taking only relevant columns
mvps = mvps[['Player', 'Year', 'Pts Won', 'Pts Max', 'Share']]
mvps
# Out:
#                 Player  Year  Pts Won  Pts Max  Share
# 0       Michael Jordan  1991    891.0      960  0.928
# 1        Magic Johnson  1991    497.0      960  0.518
# 2       David Robinson  1991    476.0      960  0.496
# 3      Charles Barkley  1991    222.0      960  0.231
# 4          Karl Malone  1991    142.0      960  0.148
# ..                 ...   ...      ...      ...    ...
# 469  Russell Westbrook  2021      5.0     1010  0.005
# 470        Ben Simmons  2021      3.0     1010  0.003
# 471       James Harden  2021      1.0     1010  0.001
# 472       LeBron James  2021      1.0     1010  0.001
# 473      Kawhi Leonard  2021      1.0     1010  0.001
#
# [474 rows x 5 columns]

# %%
players = pd.read_csv('players.csv')
players
# Out:
#        Unnamed: 0   Rk              Player Pos Age   Tm   G  GS    MP   FG  \
# 0               0    1      Alaa Abdelnaby  PF  22  POR  43   0   6.7  1.3
# 1               1    2  Mahmoud Abdul-Rauf  PG  21  DEN  67  19  22.5  6.2
# 2               2    3          Mark Acres   C  28  ORL  68   0  19.3  1.6
# 3               3    4       Michael Adams  PG  28  DEN  66  66  35.5  8.5
# 4               4    5        Mark Aguirre  SF  31  DET  78  13  25.7  5.4
# ...           ...  ...                 ...  ..  ..  ...  ..  ..   ...  ...
# 18039         725  536        Delon Wright  PG  28  SAC  27   8  25.8  3.9
# 18040         726  537      Thaddeus Young  PF  32  CHI  68  23  24.3  5.4
# 18041         727  538          Trae Young  PG  22  ATL  63  63  33.7  7.7
# 18042         728  539         Cody Zeller   C  28  CHO  48  21  20.9  3.8
# 18043         729  540         Ivica Zubac   C  23  LAC  72  33  22.3  3.6
#
#        ...  ORB  DRB  TRB   AST  STL  BLK  TOV   PF   PTS  Year
# ...

# %%
# remove columns
del players['Unnamed: 0']
del players['Rk']

# %%
players
# Out:
#                    Player Pos Age   Tm   G  GS    MP   FG   FGA   FG%  ...  \
# 0          Alaa Abdelnaby  PF  22  POR  43   0   6.7  1.3   2.7  .474  ...
# 1      Mahmoud Abdul-Rauf  PG  21  DEN  67  19  22.5  6.2  15.1  .413  ...
# 2              Mark Acres   C  28  ORL  68   0  19.3  1.6   3.1  .509  ...
# 3           Michael Adams  PG  28  DEN  66  66  35.5  8.5  21.5  .394  ...
# 4            Mark Aguirre  SF  31  DET  78  13  25.7  5.4  11.7  .462  ...
# ...                   ...  ..  ..  ...  ..  ..   ...  ...   ...   ...  ...
# 18039        Delon Wright  PG  28  SAC  27   8  25.8  3.9   8.3  .462  ...
# 18040      Thaddeus Young  PF  32  CHI  68  23  24.3  5.4   9.7  .559  ...
# 18041          Trae Young  PG  22  ATL  63  63  33.7  7.7  17.7  .438  ...
# 18042         Cody Zeller   C  28  CHO  48  21  20.9  3.8   6.8  .559  ...
# 18043         Ivica Zubac   C  23  LAC  72  33  22.3  3.6   5.5  .652  ...
#
#        ORB  DRB  TRB   AST  STL  BLK  TOV   PF   PTS  Year
# ...

# %% [markdown]
# We want to merge on player and year, but we have to clean player names in players.csv ie remove asterisk.

# %%
# remove *, dont use regular expressions for pandas
players['Player'] = players['Player'].str.replace('*', '', regex= False)

# %%
players.head(20)
# Out:
#                 Player Pos Age   Tm   G  GS    MP   FG   FGA    FG%  ...  ORB  \
# 0       Alaa Abdelnaby  PF  22  POR  43   0   6.7  1.3   2.7   .474  ...  0.6
# 1   Mahmoud Abdul-Rauf  PG  21  DEN  67  19  22.5  6.2  15.1   .413  ...  0.5
# 2           Mark Acres   C  28  ORL  68   0  19.3  1.6   3.1   .509  ...  2.1
# 3        Michael Adams  PG  28  DEN  66  66  35.5  8.5  21.5   .394  ...  0.9
# 4         Mark Aguirre  SF  31  DET  78  13  25.7  5.4  11.7   .462  ...  1.7
# 5          Danny Ainge  SG  31  POR  80   0  21.4  4.2   8.9   .472  ...  0.6
# 6          Mark Alarie  PF  27  WSB  42   1  14.0  2.4   5.4   .440  ...  1.0
# 7         Steve Alford  PG  26  DAL  34   0   6.9  1.7   3.4   .504  ...  0.3
# 8        Greg Anderson  PF  26  TOT  68   2  13.6  1.7   4.0   .430  ...  1.4
# 9        Greg Anderson  PF  26  MIL  26   0   9.5  1.0   2.8   .370  ...  1.0
# 10       Greg Anderson  PF  26  NJN   1   0  18.0  4.0   4.0  1.000  ...  4.0
# ...

# %% [markdown]
# Above we also see Greg anderson has several rows because he played for several teams. we ant him only on one line.

# %%
players.groupby(['Player', 'Year']).get_group(('Greg Anderson', 1991))
# Out:
#            Player Pos Age   Tm   G GS    MP   FG  FGA    FG%  ...  ORB  DRB  \
# 8   Greg Anderson  PF  26  TOT  68  2  13.6  1.7  4.0   .430  ...  1.4  3.3
# 9   Greg Anderson  PF  26  MIL  26  0   9.5  1.0  2.8   .370  ...  1.0  1.9
# 10  Greg Anderson  PF  26  NJN   1  0  18.0  4.0  4.0  1.000  ...  4.0  2.0
# 11  Greg Anderson  PF  26  DEN  41  2  16.1  2.1  4.7   .440  ...  1.6  4.1
#
#     TRB  AST  STL  BLK  TOV   PF  PTS  Year
# 8   4.7  0.2  0.5  0.7  1.2  2.1  4.3  1991
# 9   2.9  0.1  0.3  0.3  0.8  1.1  2.7  1991
# 10  6.0  1.0  2.0  0.0  1.0  4.0  8.0  1991
# 11  5.8  0.3  0.6  0.9  1.5  2.6  5.2  1991
#
# [4 rows x 30 columns]

# %% [markdown]
# so lets create a function that iterates through each group and makes sure each group has a single row.

# %%
def single_row(df):
    if df.shape[0] == 1:
        return df
    else:
        row = df[df['Tm'] == 'TOT']
        row['Tm'] = df.iloc[-1,:]['Tm']   # replace TOT with the last team he played for, ie team in last row
        return row
    
players = players.groupby(['Player', 'Year']).apply(single_row)

# %%
players.head(20)
# Out:
#                                  Player Pos Age   Tm   G  GS    MP   FG   FGA  \
# Player        Year
# A.C. Green    1991 164       A.C. Green  PF  27  LAL  82  21  26.4  3.1   6.6
#               1992 633       A.C. Green  PF  28  LAL  82  53  35.4  4.7   9.8
#               1993 1092      A.C. Green  PF  29  LAL  82  55  34.4  4.6   8.6
#               1994 1579      A.C. Green  PF  30  PHO  82  55  34.5  5.7  11.3
#               1995 2067      A.C. Green  SF  31  PHO  82  52  32.8  3.8   7.5
#               1996 2563      A.C. Green  SF  32  PHO  82  36  25.8  2.6   5.4
#               1997 3138      A.C. Green  PF  33  DAL  83  73  30.0  2.8   5.8
#               1998 3725      A.C. Green  PF  34  DAL  82  68  32.3  3.0   6.5
#               1999 4283      A.C. Green  PF  35  DAL  50  35  18.5  2.2   5.1
#               2000 4811      A.C. Green  PF  36  LAL  82  82  23.5  2.1   4.7
#               2001 5330      A.C. Green  PF  37  MIA  82   1  17.2  1.8   4.0
# ...

# %%
# drop new extra level index columns
players.index = players.index.droplevel()

# %%
# repeat above to drop yr index
players.index = players.index.droplevel()

# %%
players
# Out:
#               Player Pos Age   Tm   G  GS    MP   FG   FGA   FG%  ...  ORB  \
# 164       A.C. Green  PF  27  LAL  82  21  26.4  3.1   6.6  .476  ...  2.5
# 633       A.C. Green  PF  28  LAL  82  53  35.4  4.7   9.8  .476  ...  3.7
# 1092      A.C. Green  PF  29  LAL  82  55  34.4  4.6   8.6  .537  ...  3.5
# 1579      A.C. Green  PF  30  PHO  82  55  34.5  5.7  11.3  .502  ...  3.4
# 2067      A.C. Green  SF  31  PHO  82  52  32.8  3.8   7.5  .504  ...  2.4
# ...              ...  ..  ..  ...  ..  ..   ...  ...   ...   ...  ...  ...
# 6095  Željko Rebrača   C  29  DET  74   4  15.9  2.6   5.1  .505  ...  1.1
# 6595  Željko Rebrača   C  30  DET  30  12  16.3  2.7   4.8  .552  ...  0.9
# 7176  Željko Rebrača   C  31  ATL  24   2  11.4  1.4   3.2  .442  ...  1.0
# 7776  Željko Rebrača   C  32  LAC  58   2  16.0  2.3   4.0  .568  ...  0.8
# 8370  Željko Rebrača   C  33  LAC  29   2  14.2  1.8   3.3  .542  ...  0.4
#
#       DRB  TRB  AST  STL  BLK  TOV   PF   PTS  Year
# ...

# %%
# to check for single player now it becomes
players[players['Player'] == 'Greg Anderson']
# Out:
#              Player Pos Age   Tm   G  GS    MP   FG   FGA   FG%  ...  ORB  \
# 8     Greg Anderson  PF  26  DEN  68   2  13.6  1.7   4.0  .430  ...  1.4
# 467   Greg Anderson  PF  27  DEN  82  82  34.1  4.7  10.4  .456  ...  4.1
# 1412  Greg Anderson  PF  29  DET  77  47  21.1  2.6   4.8  .543  ...  2.4
# 1911  Greg Anderson  PF  30  ATL  51   0  12.2  1.1   2.0  .548  ...  1.2
# 2381  Greg Anderson  PF  31  SAS  46   7   7.5  0.5   1.0  .511  ...  0.6
# 2948  Greg Anderson   C  32  SAS  82  48  20.2  1.6   3.2  .496  ...  1.9
# 3541  Greg Anderson   C  33  ATL  50   0   8.0  0.7   1.6  .444  ...  0.8
#
#       DRB   TRB  AST  STL  BLK  TOV   PF   PTS  Year
# 8     3.3   4.7  0.2  0.5  0.7  1.2  2.1   4.3  1991
# 467   7.4  11.5  1.0  1.1  0.8  2.5  3.2  11.5  1992
# 1412  5.0   7.4  0.7  0.7  0.9  1.2  3.0   6.4  1994
# 1911  2.5   3.7  0.3  0.5  0.6  0.6  2.0   2.9  1995
# 2381  1.5   2.2  0.2  0.2  0.5  0.5  1.4   1.2  1996
# 2948  3.5   5.5  0.4  0.8  0.8  0.9  2.7   3.9  1997
# ...

# %% [markdown]
# We can now see for 1991, he has 1 row only

# %% [markdown]
# # Merging player and mvp csvs

# %% [markdown]
# We want to do outer merge because not everyone is mvp

# %%
combined = players.merge(mvps, how= 'outer', on=['Player', 'Year'])
combined.head()
# Out:
#        Player Pos Age   Tm   G  GS    MP   FG   FGA   FG%  ...  AST  STL  BLK  \
# 0  A.C. Green  PF  27  LAL  82  21  26.4  3.1   6.6  .476  ...  0.9  0.7  0.3
# 1  A.C. Green  PF  28  LAL  82  53  35.4  4.7   9.8  .476  ...  1.4  1.1  0.4
# 2  A.C. Green  PF  29  LAL  82  55  34.4  4.6   8.6  .537  ...  1.4  1.1  0.5
# 3  A.C. Green  PF  30  PHO  82  55  34.5  5.7  11.3  .502  ...  1.7  0.9  0.5
# 4  A.C. Green  SF  31  PHO  82  52  32.8  3.8   7.5  .504  ...  1.5  0.7  0.4
#
#    TOV   PF   PTS  Year Pts Won Pts Max Share
# 0  1.2  1.4   9.1  1991     NaN     NaN   NaN
# 1  1.4  1.7  13.6  1992     NaN     NaN   NaN
# 2  1.4  1.8  12.8  1993     NaN     NaN   NaN
# 3  1.2  1.7  14.7  1994     NaN     NaN   NaN
# 4  1.4  1.8  11.2  1995     NaN     NaN   NaN
#
# [5 rows x 33 columns]

# %%
combined[combined['Pts Won'] > 0]
# Out:
#               Player    Pos Age   Tm   G  GS    MP    FG   FGA   FG%  ...  \
# 187     Al Jefferson      C  29  CHA  73  73  35.0   9.6  18.8  .509  ...
# 329    Allen Iverson     PG  21  PHI  76  74  40.1   8.2  19.8  .416  ...
# 331    Allen Iverson     SG  23  PHI  48  48  41.5   9.1  22.0  .412  ...
# 332    Allen Iverson     SG  24  PHI  70  70  40.8  10.4  24.8  .421  ...
# 333    Allen Iverson     SG  25  PHI  71  71  42.0  10.7  25.5  .420  ...
# ...              ...    ...  ..  ...  ..  ..   ...   ...   ...   ...  ...
# 13587   Vince Carter     SF  23  TOR  82  82  38.1   9.6  20.7  .465  ...
# 13588   Vince Carter     SF  24  TOR  75  75  39.7  10.2  22.1  .460  ...
# 13592   Vince Carter  SF-SG  28  NJN  77  76  36.7   9.0  20.0  .452  ...
# 13952       Yao Ming      C  23  HOU  82  82  32.8   6.5  12.5  .522  ...
# 13957       Yao Ming      C  28  HOU  77  77  33.6   7.4  13.4  .548  ...
#
#        AST  STL  BLK  TOV   PF   PTS  Year Pts Won Pts Max  Share
# ...

# %%
# Replace Nans in Pts won and Pts max with 0s
combined[['Pts Won', 'Pts Max', 'Share']] = combined[['Pts Won', 'Pts Max', 'Share']].fillna(0)

# %%
# confirming
combined
# Out:
#                Player Pos Age   Tm   G  GS    MP   FG   FGA   FG%  ...  AST  \
# 0          A.C. Green  PF  27  LAL  82  21  26.4  3.1   6.6  .476  ...  0.9
# 1          A.C. Green  PF  28  LAL  82  53  35.4  4.7   9.8  .476  ...  1.4
# 2          A.C. Green  PF  29  LAL  82  55  34.4  4.6   8.6  .537  ...  1.4
# 3          A.C. Green  PF  30  PHO  82  55  34.5  5.7  11.3  .502  ...  1.7
# 4          A.C. Green  SF  31  PHO  82  52  32.8  3.8   7.5  .504  ...  1.5
# ...               ...  ..  ..  ...  ..  ..   ...  ...   ...   ...  ...  ...
# 14087  Željko Rebrača   C  29  DET  74   4  15.9  2.6   5.1  .505  ...  0.5
# 14088  Željko Rebrača   C  30  DET  30  12  16.3  2.7   4.8  .552  ...  0.3
# 14089  Željko Rebrača   C  31  ATL  24   2  11.4  1.4   3.2  .442  ...  0.3
# 14090  Željko Rebrača   C  32  LAC  58   2  16.0  2.3   4.0  .568  ...  0.4
# 14091  Željko Rebrača   C  33  LAC  29   2  14.2  1.8   3.3  .542  ...  0.3
#
# ...

# %% [markdown]
# # Cleaning Team Data

# %%
teams = pd.read_csv('teams.csv')
teams.head(20)
# Out:
#     Unnamed: 0                 W                 L              W/L%  \
# 0            0                56                26              .683
# 1            1                44                38              .537
# 2            2                39                43              .476
# 3            3                30                52              .366
# 4            4                26                56              .317
# 5            5                24                58              .293
# 6            6  Central Division  Central Division  Central Division
# 7            7                61                21              .744
# 8            8                50                32              .610
# 9            9                48                34              .585
# 10          10                43                39              .524
# 11          11                41                41              .500
# 12          12                33                49              .402
# ...

# %%
# removing the rows with division unit
teams = teams[~teams['W'].str.contains('Division')]
teams.head(20)
# Out:
#     Unnamed: 0   W   L  W/L%    GB   PS/G   PA/G     SRS  Year  \
# 0            0  56  26  .683     —  111.5  105.7    5.22  1991
# 1            1  44  38  .537  12.0  105.4  105.6   -0.39  1991
# 2            2  39  43  .476  17.0  103.1  103.3   -0.43  1991
# 3            3  30  52  .366  26.0  101.4  106.4   -4.84  1991
# 4            4  26  56  .317  30.0  102.9  107.5   -4.53  1991
# 5            5  24  58  .293  32.0  101.8  107.8   -5.91  1991
# 7            7  61  21  .744     —  110.0  101.0    8.57  1991
# 8            8  50  32  .610  11.0  100.1   96.8    3.08  1991
# 9            9  48  34  .585  13.0  106.4  104.0    2.33  1991
# 10          10  43  39  .524  18.0  109.8  109.0    0.72  1991
# 11          11  41  41  .500  20.0  111.7  112.1   -0.37  1991
# 12          12  33  49  .402  28.0  101.7  104.2   -2.33  1991
# 13          13  26  56  .317  35.0  102.8  108.0   -4.95  1991
# 15           1  55  27  .671     —  107.1  102.6    4.30  1991
# ...

# %%
# removing * in Team
teams['Team'] = teams['Team'].str.replace('*', '', regex=False)

# %%
teams.head(20)
# Out:
#     Unnamed: 0   W   L  W/L%    GB   PS/G   PA/G     SRS  Year  \
# 0            0  56  26  .683     —  111.5  105.7    5.22  1991
# 1            1  44  38  .537  12.0  105.4  105.6   -0.39  1991
# 2            2  39  43  .476  17.0  103.1  103.3   -0.43  1991
# 3            3  30  52  .366  26.0  101.4  106.4   -4.84  1991
# 4            4  26  56  .317  30.0  102.9  107.5   -4.53  1991
# 5            5  24  58  .293  32.0  101.8  107.8   -5.91  1991
# 7            7  61  21  .744     —  110.0  101.0    8.57  1991
# 8            8  50  32  .610  11.0  100.1   96.8    3.08  1991
# 9            9  48  34  .585  13.0  106.4  104.0    2.33  1991
# 10          10  43  39  .524  18.0  109.8  109.0    0.72  1991
# 11          11  41  41  .500  20.0  111.7  112.1   -0.37  1991
# 12          12  33  49  .402  28.0  101.7  104.2   -2.33  1991
# 13          13  26  56  .317  35.0  102.8  108.0   -4.95  1991
# 15           1  55  27  .671     —  107.1  102.6    4.30  1991
# ...

# %%
teams['Team'].value_counts()
# Out:
# Houston Rockets                      31
# Milwaukee Bucks                      31
# Golden State Warriors                31
# Utah Jazz                            31
# Denver Nuggets                       31
# Boston Celtics                       31
# Los Angeles Lakers                   31
# Atlanta Hawks                        31
# Portland Trail Blazers               31
# San Antonio Spurs                    31
# Chicago Bulls                        31
# Minnesota Timberwolves               31
# Los Angeles Clippers                 31
# New York Knicks                      31
# Detroit Pistons                      31
# Dallas Mavericks                     31
# Philadelphia 76ers                   31
# Miami Heat                           31
# Sacramento Kings                     31
# Indiana Pacers                       31
# Orlando Magic                        31
# Cleveland Cavaliers                  31
# Phoenix Suns                         31
# ...

# %%
combined['Tm'].value_counts()
# Out:
# CLE    499
# PHI    495
# DAL    493
# LAC    493
# GSW    492
# MIA    491
# HOU    490
# ATL    485
# DEN    480
# SAS    479
# BOS    479
# ORL    476
# MIL    475
# LAL    475
# IND    474
# CHI    473
# NYK    468
# MIN    466
# SAC    465
# UTA    464
# POR    463
# PHO    463
# DET    461
# TOR    421
# WAS    387
# NJN    343
# MEM    331
# SEA    263
# OKC    214
# CHH    177
# BRK    165
# CHA    157
# NOP    145
# NOH    143
# WSB    114
# CHO    113
# VAN     88
# NOK     32
# Name: Tm, dtype: int64

# %% [markdown]
# one uses full names, the other uses abbs

# %%
#create dict
nicknames = {}

with open ('nicknames.txt') as f:
    lines = f.readlines()
    for line in lines[1:]:
        abbbrev, name = line.replace("\n", '').split(',')
        nicknames[abbbrev] = name

# %%
# lines
combined['Team'] = combined['Tm'].map(nicknames)

# %%
#we should now have the Team names in full
combined.head(10)
# Out:
#        Player Pos Age   Tm   G  GS    MP   FG   FGA   FG%  ...  STL  BLK  TOV  \
# 0  A.C. Green  PF  27  LAL  82  21  26.4  3.1   6.6  .476  ...  0.7  0.3  1.2
# 1  A.C. Green  PF  28  LAL  82  53  35.4  4.7   9.8  .476  ...  1.1  0.4  1.4
# 2  A.C. Green  PF  29  LAL  82  55  34.4  4.6   8.6  .537  ...  1.1  0.5  1.4
# 3  A.C. Green  PF  30  PHO  82  55  34.5  5.7  11.3  .502  ...  0.9  0.5  1.2
# 4  A.C. Green  SF  31  PHO  82  52  32.8  3.8   7.5  .504  ...  0.7  0.4  1.4
# 5  A.C. Green  SF  32  PHO  82  36  25.8  2.6   5.4  .484  ...  0.5  0.3  1.0
# 6  A.C. Green  PF  33  DAL  83  73  30.0  2.8   5.8  .483  ...  0.8  0.2  0.9
# 7  A.C. Green  PF  34  DAL  82  68  32.3  3.0   6.5  .453  ...  1.0  0.3  0.8
# 8  A.C. Green  PF  35  DAL  50  35  18.5  2.2   5.1  .422  ...  0.6  0.2  0.4
# 9  A.C. Green  PF  36  LAL  82  82  23.5  2.1   4.7  .447  ...  0.6  0.2  0.6
#
#     PF   PTS  Year Pts Won Pts Max Share                Team
# ...

# %% [markdown]
# # Merge combined and teams

# %%
stats = combined.merge(teams, how= 'outer', on=['Team', 'Year'])
stats
# Out:
#                Player Pos Age   Tm   G  GS    MP   FG   FGA   FG%  ... Share  \
# 0          A.C. Green  PF  27  LAL  82  21  26.4  3.1   6.6  .476  ...   0.0
# 1         Byron Scott  SG  29  LAL  82  82  32.1  6.1  12.8  .477  ...   0.0
# 2      Elden Campbell  PF  22  LAL  52   0   7.3  1.1   2.4  .455  ...   0.0
# 3       Irving Thomas  PF  25  LAL  26   0   4.2  0.7   1.9  .340  ...   0.0
# 4        James Worthy  SF  29  LAL  78  74  38.6  9.2  18.7  .492  ...   0.0
# ...               ...  ..  ..  ...  ..  ..   ...  ...   ...   ...  ...   ...
# 14087   Spencer Hawes  PF  28  MIL  54   1  14.8  2.5   5.1  .484  ...   0.0
# 14088     Steve Novak  PF  33  MIL   8   0   2.8  0.3   0.9  .286  ...   0.0
# 14089  Terrence Jones  PF  25  MIL  54  12  23.5  4.3   9.1  .470  ...   0.0
# 14090      Thon Maker   C  19  MIL  57  34   9.9  1.5   3.2  .459  ...   0.0
# 14091      Tony Snell  SG  25  MIL  80  80  29.2  3.1   6.8  .455  ...   0.0
#
# ...

# %%
# to know merge went well usually no of rows remains the same
combined
# Out:
#                Player Pos Age   Tm   G  GS    MP   FG   FGA   FG%  ...  STL  \
# 0          A.C. Green  PF  27  LAL  82  21  26.4  3.1   6.6  .476  ...  0.7
# 1          A.C. Green  PF  28  LAL  82  53  35.4  4.7   9.8  .476  ...  1.1
# 2          A.C. Green  PF  29  LAL  82  55  34.4  4.6   8.6  .537  ...  1.1
# 3          A.C. Green  PF  30  PHO  82  55  34.5  5.7  11.3  .502  ...  0.9
# 4          A.C. Green  SF  31  PHO  82  52  32.8  3.8   7.5  .504  ...  0.7
# ...               ...  ..  ..  ...  ..  ..   ...  ...   ...   ...  ...  ...
# 14087  Željko Rebrača   C  29  DET  74   4  15.9  2.6   5.1  .505  ...  0.4
# 14088  Željko Rebrača   C  30  DET  30  12  16.3  2.7   4.8  .552  ...  0.2
# 14089  Željko Rebrača   C  31  ATL  24   2  11.4  1.4   3.2  .442  ...  0.2
# 14090  Željko Rebrača   C  32  LAC  58   2  16.0  2.3   4.0  .568  ...  0.2
# 14091  Željko Rebrača   C  33  LAC  29   2  14.2  1.8   3.3  .542  ...  0.2
#
# ...

# %%
stats
# Out:
#                Player Pos Age   Tm   G  GS    MP   FG   FGA   FG%  ... Share  \
# 0          A.C. Green  PF  27  LAL  82  21  26.4  3.1   6.6  .476  ...   0.0
# 1         Byron Scott  SG  29  LAL  82  82  32.1  6.1  12.8  .477  ...   0.0
# 2      Elden Campbell  PF  22  LAL  52   0   7.3  1.1   2.4  .455  ...   0.0
# 3       Irving Thomas  PF  25  LAL  26   0   4.2  0.7   1.9  .340  ...   0.0
# 4        James Worthy  SF  29  LAL  78  74  38.6  9.2  18.7  .492  ...   0.0
# ...               ...  ..  ..  ...  ..  ..   ...  ...   ...   ...  ...   ...
# 14087   Spencer Hawes  PF  28  MIL  54   1  14.8  2.5   5.1  .484  ...   0.0
# 14088     Steve Novak  PF  33  MIL   8   0   2.8  0.3   0.9  .286  ...   0.0
# 14089  Terrence Jones  PF  25  MIL  54  12  23.5  4.3   9.1  .470  ...   0.0
# 14090      Thon Maker   C  19  MIL  57  34   9.9  1.5   3.2  .459  ...   0.0
# 14091      Tony Snell  SG  25  MIL  80  80  29.2  3.1   6.8  .455  ...   0.0
#
# ...

# %%
del stats['Unnamed: 0']

# %%
stats.dtypes
# Out:
# Player      object
# Pos         object
# Age         object
# Tm          object
# G           object
# GS          object
# MP          object
# FG          object
# FGA         object
# FG%         object
# 3P          object
# 3PA         object
# 3P%         object
# 2P          object
# 2PA         object
# 2P%         object
# eFG%        object
# FT          object
# FTA         object
# FT%         object
# ORB         object
# DRB         object
# TRB         object
# AST         object
# STL         object
# BLK         object
# TOV         object
# PF          object
# PTS         object
# Year         int64
# Pts Won    float64
# Pts Max    float64
# Share      float64
# Team        object
# W           object
# L           object
# W/L%        object
# GB          object
# PS/G        object
# PA/G        object
# SRS         object
# dtype: object

# %%
# convert dtypes from object to numeric
stats = stats.apply(pd.to_numeric, errors = 'ignore')

# %%
stats.dtypes
# Out:
# Player      object
# Pos         object
# Age          int64
# Tm          object
# G            int64
# GS           int64
# MP         float64
# FG         float64
# FGA        float64
# FG%        float64
# 3P         float64
# 3PA        float64
# 3P%        float64
# 2P         float64
# 2PA        float64
# 2P%        float64
# eFG%       float64
# FT         float64
# FTA        float64
# FT%        float64
# ORB        float64
# DRB        float64
# TRB        float64
# AST        float64
# STL        float64
# BLK        float64
# TOV        float64
# PF         float64
# PTS        float64
# Year         int64
# Pts Won    float64
# Pts Max    float64
# Share      float64
# Team        object
# W            int64
# L            int64
# W/L%       float64
# GB          object
# PS/G       float64
# PA/G       float64
# SRS        float64
# dtype: object

# %%
# however GB still object
stats['GB'].unique()
# Out:
# array(['5.0', '14.0', '23.0', '7.0', '—', '40.0', '42.0', '18.0', '6.0',
#        '24.0', '26.0', '37.0', '29.0', '21.0', '28.0', '25.0', '8.0',
#        '19.0', '1.0', '13.0', '17.0', '3.0', '15.0', '9.0', '2.0', '35.0',
#        '20.0', '11.0', '16.0', '41.0', '12.0', '50.0', '10.0', '30.0',
#        '34.0', '4.0', '1.5', '22.0', '51.0', '36.0', '43.0', '39.0',
#        '18.5', '48.0', '46.0', '10.5', '32.0', '38.0', '27.0', '33.0',
#        '31.0', '21.5', '45.0', '22.5', '25.5', '3.5', '20.5', '11.5',
#        '44.0', '52.0', '56.0', '2.5', '12.5', '47.0', '32.5', '4.5'],
#       dtype=object)

# %%
# remove —
stats['GB'] = stats['GB'].str.replace('—', '0')

# %%
stats['GB'].unique()
# Out:
# array(['5.0', '14.0', '23.0', '7.0', '0', '40.0', '42.0', '18.0', '6.0',
#        '24.0', '26.0', '37.0', '29.0', '21.0', '28.0', '25.0', '8.0',
#        '19.0', '1.0', '13.0', '17.0', '3.0', '15.0', '9.0', '2.0', '35.0',
#        '20.0', '11.0', '16.0', '41.0', '12.0', '50.0', '10.0', '30.0',
#        '34.0', '4.0', '1.5', '22.0', '51.0', '36.0', '43.0', '39.0',
#        '18.5', '48.0', '46.0', '10.5', '32.0', '38.0', '27.0', '33.0',
#        '31.0', '21.5', '45.0', '22.5', '25.5', '3.5', '20.5', '11.5',
#        '44.0', '52.0', '56.0', '2.5', '12.5', '47.0', '32.5', '4.5'],
#       dtype=object)

# %%
# no covert GB to numeric
stats['GB'] = pd.to_numeric(stats['GB'])

# %%
stats.dtypes
# Out:
# Player      object
# Pos         object
# Age          int64
# Tm          object
# G            int64
# GS           int64
# MP         float64
# FG         float64
# FGA        float64
# FG%        float64
# 3P         float64
# 3PA        float64
# 3P%        float64
# 2P         float64
# 2PA        float64
# 2P%        float64
# eFG%       float64
# FT         float64
# FTA        float64
# FT%        float64
# ORB        float64
# DRB        float64
# TRB        float64
# AST        float64
# STL        float64
# BLK        float64
# TOV        float64
# PF         float64
# PTS        float64
# Year         int64
# Pts Won    float64
# Pts Max    float64
# Share      float64
# Team        object
# W            int64
# L            int64
# W/L%       float64
# GB         float64
# PS/G       float64
# PA/G       float64
# SRS        float64
# dtype: object

# %%
# write to csv to use in ML
stats.to_csv('player_mvp_stats.csv')

# %% [markdown]
# # Exploring Data

# %%
# highest scoring who played over 70 games since 1991
highest_scoring = stats[stats['G'] > 70].sort_values('PTS', ascending = False).head(10)
highest_scoring
# Out:
#                  Player Pos  Age   Tm   G  GS    MP    FG   FGA    FG%  ...  \
# 9634       James Harden  PG   29  HOU  78  78  36.8  10.8  24.5  0.442  ...
# 1051        Kobe Bryant  SG   27  LAL  80  80  41.0  12.2  27.2  0.450  ...
# 4425      Allen Iverson  PG   30  PHI  72  72  43.1  11.3  25.3  0.447  ...
# 9953     Michael Jordan  SG   29  CHI  78  78  39.3  12.7  25.7  0.495  ...
# 6871      Tracy McGrady  SG   23  ORL  75  74  39.4  11.1  24.2  0.457  ...
# 6300       Kevin Durant  SF   25  OKC  81  81  38.5  10.5  20.8  0.503  ...
# 6352  Russell Westbrook  PG   28  OKC  81  81  34.6  10.2  24.0  0.425  ...
# 1065        Kobe Bryant  SG   28  LAL  77  77  40.8  10.6  22.8  0.463  ...
# 9927     Michael Jordan  SG   27  CHI  82  82  37.0  12.1  22.4  0.539  ...
# 3263       LeBron James  SF   21  CLE  79  79  42.5  11.1  23.1  0.480  ...
#
#       Pts Max  Share                   Team   W   L   W/L%    GB   PS/G  \
# ...

# %%
highest_scoring.plot.bar('Player', 'PTS')
# Out:
# <AxesSubplot:xlabel='Player'>

# %% [markdown]
# #### Checking who scored the highest each year

# %%
highest_scoring = stats.groupby('Year').apply(lambda x: x.sort_values('PTS', ascending = False).head(1))

# %%
highest_scoring.plot.bar('Player', 'PTS')
# Out:
# <AxesSubplot:xlabel='Player'>

# %%
highest_scoring.plot.bar('Year', 'PTS')
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
#checking for correlations with share
stats.corr()['Share']
# Out:
# Age        0.018596
# G          0.089282
# GS         0.167476
# MP         0.162175
# FG         0.276365
# FGA        0.249254
# FG%        0.065789
# 3P         0.096225
# 3PA        0.096460
# 3P%        0.013611
# 2P         0.275976
# 2PA        0.251885
# 2P%        0.063240
# eFG%       0.059335
# FT         0.316392
# FTA        0.321457
# FT%        0.037875
# ORB        0.101375
# DRB        0.213241
# TRB        0.186209
# AST        0.200253
# STL        0.175041
# BLK        0.154713
# TOV        0.233015
# PF         0.071046
# PTS        0.288267
# Year      -0.008135
# Pts Won    0.995153
# Pts Max    0.521335
# Share      1.000000
# W          0.122718
# L         -0.121866
# W/L%       0.126559
# GB        -0.101014
# PS/G       0.045206
# PA/G      -0.039617
# SRS        0.122782
# Name: Share, dtype: float64

# %%
stats.corr()['Share'].plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Machine Learning

# %%
stats
# Out:
#                Player Pos  Age   Tm   G  GS    MP   FG   FGA    FG%  ...  \
# 0          A.C. Green  PF   27  LAL  82  21  26.4  3.1   6.6  0.476  ...
# 1         Byron Scott  SG   29  LAL  82  82  32.1  6.1  12.8  0.477  ...
# 2      Elden Campbell  PF   22  LAL  52   0   7.3  1.1   2.4  0.455  ...
# 3       Irving Thomas  PF   25  LAL  26   0   4.2  0.7   1.9  0.340  ...
# 4        James Worthy  SF   29  LAL  78  74  38.6  9.2  18.7  0.492  ...
# ...               ...  ..  ...  ...  ..  ..   ...  ...   ...    ...  ...
# 14087   Spencer Hawes  PF   28  MIL  54   1  14.8  2.5   5.1  0.484  ...
# 14088     Steve Novak  PF   33  MIL   8   0   2.8  0.3   0.9  0.286  ...
# 14089  Terrence Jones  PF   25  MIL  54  12  23.5  4.3   9.1  0.470  ...
# 14090      Thon Maker   C   19  MIL  57  34   9.9  1.5   3.2  0.459  ...
# 14091      Tony Snell  SG   25  MIL  80  80  29.2  3.1   6.8  0.455  ...
#
#        Pts Max  Share                Team   W   L   W/L%   GB   PS/G   PA/G  \
# ...

# %% [markdown]
# #### ML dont like null values, so lets remove

# %%
stats.isna().sum()
# Out:
# Player        0
# Pos           0
# Age           0
# Tm            0
# G             0
# GS            0
# MP            0
# FG            0
# FGA           0
# FG%          50
# 3P            0
# 3PA           0
# 3P%        2042
# 2P            0
# 2PA           0
# 2P%          84
# eFG%         50
# FT            0
# FTA           0
# FT%         462
# ORB           0
# DRB           0
# TRB           0
# AST           0
# STL           0
# BLK           0
# TOV           0
# PF            0
# PTS           0
# Year          0
# Pts Won       0
# Pts Max       0
# Share         0
# Team          0
# W             0
# L             0
# W/L%          0
# GB            0
# PS/G          0
# PA/G          0
# SRS           0
# dtype: int64

# %% [markdown]
# The nulls we see are in percentages ie 3P%. This can mean the player never attempted any 3pointers as the percentage is gotten from 3P/3PAttempted

# %%
#checking 3P% nulls in player and 3PA 
stats[pd.isna(stats['3P%'])][['Player', '3PA']]
# Out:
#                  Player  3PA
# 2        Elden Campbell  0.0
# 3         Irving Thomas  0.0
# 18           Jack Haley  0.0
# 20          Keith Owens  0.0
# 30      Benoit Benjamin  0.0
# ...                 ...  ...
# 14061    Evan Eschmeyer  0.0
# 14062  Gheorghe Mureșan  0.0
# 14064     Jim McIlvaine  0.0
# 14070  Mark Hendrickson  0.0
# 14071      Michael Cage  0.0
#
# [2042 rows x 2 columns]

# %% [markdown]
# We can see that the players with nulls have 0 attempted 3 pointers.

# %%
# doing the same with free throws(FT)
stats[pd.isna(stats['FT%'])][['Player', 'FTA']]
# Out:
#                 Player  FTA
# 77          John Coker  0.0
# 92        Jason Sasser  0.0
# 103    Adrian Caldwell  0.0
# 119       Bruno Šundov  0.0
# 158     Jamal Robinson  0.0
# ...                ...  ...
# 13951    Mark McNamara  0.0
# 13979      Luke Zeller  0.0
# 14032      Myron Brown  0.0
# 14054      Malcolm Lee  0.0
# 14088      Steve Novak  0.0
#
# [462 rows x 2 columns]

# %% [markdown]
# Also, here players have 0 attempts. so we'll use fillna

# %%
stats = stats.fillna(0)

# %%
stats.isna().sum()
# Out:
# Player     0
# Pos        0
# Age        0
# Tm         0
# G          0
# GS         0
# MP         0
# FG         0
# FGA        0
# FG%        0
# 3P         0
# 3PA        0
# 3P%        0
# 2P         0
# 2PA        0
# 2P%        0
# eFG%       0
# FT         0
# FTA        0
# FT%        0
# ORB        0
# DRB        0
# TRB        0
# AST        0
# STL        0
# BLK        0
# TOV        0
# PF         0
# PTS        0
# Year       0
# Pts Won    0
# Pts Max    0
# Share      0
# Team       0
# W          0
# L          0
# W/L%       0
# GB         0
# PS/G       0
# PA/G       0
# SRS        0
# dtype: int64

# %% [markdown]
# #### Starting MODELLING

# %%
stats.columns
# Out:
# Index(['Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P',
#        '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB',
#        'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Year',
#        'Pts Won', 'Pts Max', 'Share', 'Team', 'W', 'L', 'W/L%', 'GB', 'PS/G',
#        'PA/G', 'SRS'],
#       dtype='object')

# %%
# using numeric columns only, and removing mvp column table and target to not bias ML models
predictors = ['Age', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P',
       '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB',
       'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'Year',
        'W', 'L', 'W/L%', 'GB', 'PS/G',
       'PA/G', 'SRS']

# %%
#set train data
train = stats[stats['Year'] < 2021]

# %%
#set test data
test = stats[stats['Year'] == 2021]

# %%
#Ridge shrinks the linreg coefficients to avoid over fitting
from sklearn.linear_model import Ridge

reg = Ridge(alpha= .1)    # alpha controls how much coefficients are shrunk

# %%
#fit model
reg.fit(train[predictors], train['Share'])
# Out:
# Ridge(alpha=0.1)

# %%
predictions = reg.predict(test[predictors])
#predictions

# %%
# converting predictions from np arrays to Dataframe for easy visibility
# and creating column for predicted predictions

predictions = pd.DataFrame(predictions, columns=['predictions'], index = test.index)

# %%
predictions
# Out:
#        predictions
# 630       0.013567
# 631      -0.013756
# 632       0.002414
# 633      -0.004421
# 634       0.010734
# ...            ...
# 13897    -0.012571
# 13898    -0.011575
# 13899     0.016424
# 13900    -0.020434
# 13901    -0.005421
#
# [540 rows x 1 columns]

# %% [markdown]
# #### Now lets combine this and previous df to compare predicted and actual values of SHARE

# %%
combination = pd.concat([test[['Player', 'Share']], predictions], axis= 1)
combination
# Out:
#                        Player  Share  predictions
# 630              Aaron Gordon    0.0     0.013567
# 631             Austin Rivers    0.0    -0.013756
# 632                   Bol Bol    0.0     0.002414
# 633          Facundo Campazzo    0.0    -0.004421
# 634          Greg Whittington    0.0     0.010734
# ...                       ...    ...          ...
# 13897             Patty Mills    0.0    -0.012571
# 13898  Quinndary Weatherspoon    0.0    -0.011575
# 13899                Rudy Gay    0.0     0.016424
# 13900               Tre Jones    0.0    -0.020434
# 13901              Trey Lyles    0.0    -0.005421
#
# [540 rows x 3 columns]

# %%
combination.sort_values('Share', ascending= False).head(10)
# Out:
#                       Player  Share  predictions
# 641             Nikola Jokić  0.961     0.154307
# 8624             Joel Embiid  0.580     0.162713
# 3651           Stephen Curry  0.449     0.142386
# 9907   Giannis Antetokounmpo  0.345     0.207436
# 1389              Chris Paul  0.138     0.072294
# 10997            Luka Dončić  0.042     0.151430
# 7464          Damian Lillard  0.038     0.116303
# 3536           Julius Randle  0.020     0.088878
# 3531            Derrick Rose  0.010     0.033000
# 11358            Rudy Gobert  0.008     0.095349

# %% [markdown]
# #### Its really hard to predict the rank from what we can see, but lets pick an error metric first

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(combination['Share'], combination['predictions'])
# Out:
# 0.0026668954567104024

# %%
combination['Share'].value_counts()
# Out:
# 0.000    525
# 0.001      3
# 0.961      1
# 0.138      1
# 0.042      1
# 0.038      1
# 0.020      1
# 0.003      1
# 0.008      1
# 0.005      1
# 0.580      1
# 0.449      1
# 0.010      1
# 0.345      1
# Name: Share, dtype: int64

# %% [markdown]
# 0 doing the most. Most players in NBA dont get any MVP votes.
#
# This error metric doesnt work for us. We need a new one that thinks about the rank of the player.

# %%
combination = combination.sort_values('Share', ascending= False)
combination['Rk'] = list(range(1, combination.shape[0]+1))

# %%
combination.head(10)
# Out:
#                       Player  Share  predictions  Rk
# 641             Nikola Jokić  0.961     0.154307   1
# 8624             Joel Embiid  0.580     0.162713   2
# 3651           Stephen Curry  0.449     0.142386   3
# 9907   Giannis Antetokounmpo  0.345     0.207436   4
# 1389              Chris Paul  0.138     0.072294   5
# 10997            Luka Dončić  0.042     0.151430   6
# 7464          Damian Lillard  0.038     0.116303   7
# 3536           Julius Randle  0.020     0.088878   8
# 3531            Derrick Rose  0.010     0.033000   9
# 11358            Rudy Gobert  0.008     0.095349  10

# %%
combination = combination.sort_values('predictions', ascending= False)
combination['Predicted_Rk'] = list(range(1, combination.shape[0]+1))

# %%
combination.head(10)
# Out:
#                       Player  Share  predictions   Rk  Predicted_Rk
# 9907   Giannis Antetokounmpo  0.345     0.207436    4             1
# 8624             Joel Embiid  0.580     0.162713    2             2
# 641             Nikola Jokić  0.961     0.154307    1             3
# 10997            Luka Dončić  0.042     0.151430    6             4
# 3736            LeBron James  0.001     0.147511   15             5
# 3651           Stephen Curry  0.449     0.142386    3             6
# 4177            Kevin Durant  0.000     0.141350  531             7
# 4174            James Harden  0.001     0.140598   13             8
# 11784        Zion Williamson  0.000     0.127926  251             9
# 3876       Russell Westbrook  0.005     0.120228   11            10

# %% [markdown]
# #### Of the TOP 5 mvp players, how many did we place in top 5
# #### Using AVERAGE PRECISION - it deals with ranking

# %%
combination.sort_values('Share', ascending= False).head(10)
# Out:
#                       Player  Share  predictions  Rk  Predicted_Rk
# 641             Nikola Jokić  0.961     0.154307   1             3
# 8624             Joel Embiid  0.580     0.162713   2             2
# 3651           Stephen Curry  0.449     0.142386   3             6
# 9907   Giannis Antetokounmpo  0.345     0.207436   4             1
# 1389              Chris Paul  0.138     0.072294   5            33
# 10997            Luka Dončić  0.042     0.151430   6             4
# 7464          Damian Lillard  0.038     0.116303   7            12
# 3536           Julius Randle  0.020     0.088878   8            24
# 3531            Derrick Rose  0.010     0.033000   9            76
# 11358            Rudy Gobert  0.008     0.095349  10            19

# %%
# sort df by share and take top 5 mvps
def find_ap(combination):
    actual = combination.sort_values('Share', ascending= False).head(5)
    predicted = combination.sort_values('predictions', ascending= False)
    ps = []
    found = 0
    seen = 1
    for index, row in predicted.iterrows():
        if row['Player'] in actual['Player'].values:
            found += 1
            ps.append(found/seen)
        seen += 1
    return sum(ps)/len(ps)    # to find error metric

# %%
find_ap(combination)
# Out:
# 0.7636363636363636

# %% [markdown]
# # Backtesting

# %%
# lets run it for all years now
years = list(range(1991, 2022))

# %%
aps = []
all_predictions = []
for year in years[5:]:
    train = stats[stats["Year"] < year]
    test = stats[stats["Year"] == year]
    reg.fit(train[predictors],train["Share"])
    predictions = reg.predict(test[predictors])
    predictions = pd.DataFrame(predictions, columns=["predictions"], index=test.index)
    combination = pd.concat([test[["Player", "Share"]], predictions], axis=1)
    all_predictions.append(combination)
    aps.append(find_ap(combination))

# %%
sum(aps) / len(aps)    #mean average precision(ap)
# Out:
# 0.7112884360789578

# %%
def add_ranks(predictions):
    predictions = predictions.sort_values("predictions", ascending=False)
    predictions["Predicted_Rk"] = list(range(1,predictions.shape[0]+1))
    predictions = predictions.sort_values("Share", ascending=False)
    predictions["Rk"] = list(range(1,predictions.shape[0]+1))
    predictions["Diff"] = (predictions["Rk"] - predictions["Predicted_Rk"])
    return predictions

# %%
add_ranks(all_predictions[1])
# Out:
#                 Player  Share  predictions  Predicted_Rk   Rk  Diff
# 1600       Karl Malone  0.857     0.192318             2    1    -1
# 10524   Michael Jordan  0.832     0.167629             3    2    -1
# 908         Grant Hill  0.327     0.128646             6    3    -3
# 4682      Tim Hardaway  0.207     0.059984            20    4   -16
# 8248         Glen Rice  0.117     0.033110            53    5   -48
# ...                ...    ...          ...           ...  ...   ...
# 10136   Horacio Llamas  0.000     0.010171           156  437   281
# 3576     Ennis Whatley  0.000     0.010250           155  438   283
# 10594  Kevin Salvadori  0.000     0.010553           154  439   285
# 1138    Aaron Williams  0.000     0.010594           153  440   287
# 6792     Melvin Booker  0.000    -0.055185           441  441     0
#
# [441 rows x 6 columns]

# %% [markdown]
# #### The function below summarizes all works above

# %%
def backtest(stats, model, years, predictors):
    aps = []
    all_predictions = []
    for year in years:
        train = stats[stats["Year"] < year]
        test = stats[stats["Year"] == year]
        model.fit(train[predictors],train["Share"])
        predictions = model.predict(test[predictors])
        predictions = pd.DataFrame(predictions, columns=["predictions"], index=test.index)
        combination = pd.concat([test[["Player", "Share"]], predictions], axis=1)
        combination = add_ranks(combination)
        all_predictions.append(combination)
        aps.append(find_ap(combination))
    return sum(aps) / len(aps), aps, pd.concat(all_predictions)

# %%
mean_ap, aps, all_predictions = backtest(stats, reg, years[5:], predictors)

# %%
mean_ap
# Out:
# 0.7112884360789578

# %%
all_predictions[all_predictions["Rk"] < 5].sort_values("Diff").head(10)
# Out:
#                 Player  Share  predictions  Predicted_Rk  Rk  Diff
# 1224        Jason Kidd  0.712     0.028209            52   2   -50
# 5175        Steve Nash  0.839     0.034100            45   1   -44
# 8516   Peja Stojaković  0.228     0.036269            38   4   -34
# 12726      Joakim Noah  0.258     0.046968            37   4   -33
# 5193        Steve Nash  0.739     0.054128            34   1   -33
# 5208        Steve Nash  0.785     0.074421            21   2   -19
# 4682      Tim Hardaway  0.207     0.059984            20   4   -16
# 937      Allen Iverson  0.270     0.072120            14   4   -10
# 6746       Kobe Bryant  0.291     0.078014            14   4   -10
# 1157       Gary Payton  0.372     0.076708            13   3   -10

# %%
reg.coef_
# Out:
# array([ 3.21225799e-04,  9.16295119e-05, -5.62287893e-06, -4.14969303e-03,
#         5.69435368e-03,  5.51627207e-03, -1.35025345e-01,  4.56936500e-03,
#        -1.03942800e-02, -9.82179223e-03,  1.69452132e-02, -1.73181709e-02,
#         4.08318282e-03,  7.00021750e-02, -6.58501469e-03,  1.13509610e-02,
#        -4.57492793e-03,  2.16104448e-02,  3.50411278e-02, -2.75059354e-02,
#         7.45553644e-03,  1.16354220e-02,  1.12337946e-02, -9.69644454e-03,
#        -2.63402385e-03,  5.89333750e-03, -1.84247808e-04,  9.78858335e-05,
#        -2.95483880e-04,  2.71257474e-02,  2.69641841e-04, -5.56160227e-04,
#        -2.18797486e-04, -5.21394525e-04])

# %%
# changing coef to pd series for easy readability
pd.concat([pd.Series(reg.coef_), pd.Series(predictors)], axis=1).sort_values(0, ascending=False)
# Out:
#            0     1
# 13  0.070002  eFG%
# 18  0.035041   DRB
# 29  0.027126  W/L%
# 17  0.021610   ORB
# 10  0.016945    2P
# 21  0.011635   STL
# 15  0.011351   FTA
# 22  0.011234   BLK
# 20  0.007456   AST
# 25  0.005893   PTS
# 4   0.005694    FG
# 5   0.005516   FGA
# 7   0.004569    3P
# 12  0.004083   2P%
# 0   0.000321   Age
# 30  0.000270    GB
# 27  0.000098     W
# 1   0.000092     G
# 2  -0.000006    GS
# 26 -0.000184  Year
# 32 -0.000219  PA/G
# 28 -0.000295     L
# 33 -0.000521   SRS
# 31 -0.000556  PS/G
# 24 -0.002634    PF
# 3  -0.004150    MP
# 16 -0.004575   FT%
# 14 -0.006585    FT
# 23 -0.009696   TOV
# 9  -0.009822   3P%
# 8  -0.010394   3PA
# 11 -0.017318   2PA
# 19 -0.027506   TRB
# 6  -0.135025   FG%

# %% [markdown]
# #### Lets add more predictors

# %%
stat_ratios = stats[["PTS", "AST", "STL", "BLK", "3P", "Year"]].groupby("Year").apply(lambda x: x/x.mean())
stat_ratios
# Out:
#             PTS       AST       STL       BLK        3P  Year
# 0      1.013334  0.420714  0.961127  0.673469  0.508587   1.0
# 1      1.614653  1.028412  1.647646  0.673469  4.577279   1.0
# 2      0.311795  0.093492  0.274608  1.571429  0.000000   1.0
# 3      0.200440  0.186984  0.274608  0.000000  0.000000   1.0
# 4      2.383005  1.636110  1.784950  0.897959  1.525760   1.0
# ...         ...       ...       ...       ...       ...   ...
# 14087  0.735752  0.819562  0.479763  1.528302  0.650951   1.0
# 14088  0.071202  0.000000  0.000000  0.000000  0.130190   1.0
# 14089  1.281633  0.601012  1.119447  2.547170  0.520761   1.0
# 14090  0.474679  0.218550  0.319842  1.273585  0.650951   1.0
# 14091  1.008693  0.655649  1.119447  0.509434  2.343424   1.0
#
# [14092 rows x 6 columns]

# %%
# add to stats df
stats[["PTS_R", "AST_R", "STL_R", "BLK_R", "3P_R"]] = stat_ratios[["PTS", "AST", "STL", "BLK", "3P"]]
stats
# Out:
#                Player Pos  Age   Tm   G  GS    MP   FG   FGA    FG%  ...  \
# 0          A.C. Green  PF   27  LAL  82  21  26.4  3.1   6.6  0.476  ...
# 1         Byron Scott  SG   29  LAL  82  82  32.1  6.1  12.8  0.477  ...
# 2      Elden Campbell  PF   22  LAL  52   0   7.3  1.1   2.4  0.455  ...
# 3       Irving Thomas  PF   25  LAL  26   0   4.2  0.7   1.9  0.340  ...
# 4        James Worthy  SF   29  LAL  78  74  38.6  9.2  18.7  0.492  ...
# ...               ...  ..  ...  ...  ..  ..   ...  ...   ...    ...  ...
# 14087   Spencer Hawes  PF   28  MIL  54   1  14.8  2.5   5.1  0.484  ...
# 14088     Steve Novak  PF   33  MIL   8   0   2.8  0.3   0.9  0.286  ...
# 14089  Terrence Jones  PF   25  MIL  54  12  23.5  4.3   9.1  0.470  ...
# 14090      Thon Maker   C   19  MIL  57  34   9.9  1.5   3.2  0.459  ...
# 14091      Tony Snell  SG   25  MIL  80  80  29.2  3.1   6.8  0.455  ...
#
#         W/L%   GB   PS/G   PA/G   SRS     PTS_R     AST_R     STL_R     BLK_R  \
# ...

# %% [markdown]
# We have new columns at the end, add to predictors.

# %%
predictors += ["PTS_R", "AST_R", "STL_R", "BLK_R", "3P_R"]

# %%
mean_ap, aps, all_predictions = backtest(stats, reg, years[5:], predictors)

# %%
mean_ap
# Out:
# 0.7208380973034985

# %% [markdown]
# It has improved mean AVERAGE PRECISION by .1

# %%
# using Pos column
stats['Pos'].unique()
# Out:
# array(['PF', 'SG', 'SF', 'PG', 'C', 'PG-SG', 'PF-SF', 'SG-PG', 'PF-C',
#        'SG-SF', 'SF-PF', 'SF-SG', 'C-PF', 'SG-PF', 'PG-SF', 'SF-C'],
#       dtype=object)

# %%
stats["NPos"] = stats["Pos"].astype("category").cat.codes
stats["NTm"] = stats["Tm"].astype("category").cat.codes

# %% [markdown]
# # RandomForest

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(n_estimators=50, random_state=1, min_samples_split=5)

mean_ap, aps, all_predictions = backtest(stats, rf, years[28:], predictors + ["NPos", "NTm"])

# %%
years[28]    #it will only start making predictions from 2019
# Out:
# 2019

# %%
mean_ap
# Out:
# 0.8141954559601619

# %%
mean_ap, aps, all_predictions = backtest(stats, reg, years[28:], predictors)

# %%
mean_ap
# Out:
# 0.7981818181818182
